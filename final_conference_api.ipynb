# %%
import requests
frome datetime import timedelta
"""YYYY-MM-DD
timdelta = duration expressing the difference between two date, time or datetime"""
import json


# Simple request
# """Requesting the data from the API"""
# res = requests.get('https://ct-mock-tech-assessment.herokuapp.com/')
# data = res.json['partners']

class Invites:
    
    def __init__(self, r):
        """Instantiate avalaible emails to dictionary"""
        self.info = {
        'attendeeCount': attendees.count('email'),
        'attendees': r['emails'],
        'country': r['country'],
        'startDate' : r['availableDates']
        }
        
        
    def post_request(self)
    """Post to API"""
    requests.post('https://ct-mock-tech-assessment.herokuapp.com/', self.info ).json
    print(self.info.status_code)
    pass

class Control:
    
    def __init__(self):
        """Append instantiated items to list"""
        self.info = []
        
    def find_dates(self, data):
        """Run through dates and figure out which one works - use datetime"""
#         self.data = (request.get('https://ct-mock-tech-assessment.herokuapp.com/')).json['partners']
        for dates in availableDates:
            if 
        
    def find_emails(self):
        """Find emails with available dates and append to self.info through Invites"""
        
        """Creates list by country"""
        for r in data['partners']:
            if r['country'] not in new_dict.keys():
                new_dict[r['country']]  = [r] 
            else:
                new_dict[r['country']].append(r['email'])


        
# class Dates:
    

# Create 2 classes: Are attendess an inheirited class?
#     - class Invites: Instantiates the people available
#     - class Attendees: Runs through API and pulls available date while instantiating into Invites
# Last method updates API
# Out:
#   File "<ipython-input-1-62ee72a8faec>", line 32
#     # Last method updates API
#                                      ^
# IndentationError: expected an indented block

# %%
import json
from datetime import datetime, timedelta
import requests
"""Requesting the data from the API"""
res = requests.get('https://ct-mock-tech-assessment.herokuapp.com/')
data = res.json()['partners']

# print(data)

for r in data:
    availability = r['availableDates']
    country = r['country']
    email = r['email']
    first_name = r['firstName']
    last_name = r['lastName']
#     print(first_name, last_name, email, country)
#     print(country, availability)
new_dict = {}

for k,v in new_dict.items():
    if country not in new_dict:
        new_dict[country] = country
    else:
        new_dict[country] = availability
print(new_dict)

    
# for a in availability:
#     a = datetime.strptime(a, "%Y-%m-%d").date()
#     print(a)
# Out:
# {}

# %%
# 'https://ct-mock-tech-assessment.herokuapp.com/'
import requests
import datetime
import json

class InviteList:
    
    def __init__(self, r):
        """Instantiate invite list"""
    
    pass

class Dates:
    
    def find_date(self, _date):
        """Iterate through API and most common available range of two dates"""
        
    def find_email(self, _email):
        """Iterate through list and find the people who can attend on their country date"""
        
    pass

class Control:
    
    def __init__(self):
        self.list = []
        
    def read_api(self):
        """Make API more manageable"""
        
    def create_invites(self):
        """Instantiate InviteList using return from find_email"""
        can_attend = InviteList(requests.get('https://ct-mock-tech-assessment.herokuapp.com/').json)
        
    def post_invites(self):
        """Post the InviteList back to the API"""
    pass
